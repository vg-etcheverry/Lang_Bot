# %% [markdown]
# <a href="https://colab.research.google.com/github/vg-etcheverry/Lang_Bot/blob/main/LangBot_Direto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# !pip install -q -U unidecode
from IPython.display import Markdown
from IPython.display import display, HTML
from unidecode import unidecode
from google.colab import userdata, runtime

import google.generativeai as genAi
import sys

GOOGLE_API_KEY=userdata.get('api')
genAi.configure(api_key=GOOGLE_API_KEY)

def print_md(text):
    display(Markdown(text))
def print_html(html_code):
  htmlInicio = "<html><body>"
  htmlFim = "</body></html>"
  htmlFinal = htmlInicio + html_code + htmlFim
  display(HTML(htmlFinal))
print("Iniciação OK")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.0 MB/s eta 0:00:00
# Iniciação OK

# %%
#inicio variaveis fixas
nomeModelo = 'gemini-1.5-pro-latest'
genConfig = {
    "candidate_count": 1,
    "temperature": 1
}
model = genAi.GenerativeModel(
    model_name=nomeModelo,
    generation_config=genConfig
)

idioma = {
    'input': '',
    'listaSemAcento': ['Alemao','Basco','Catalao','Checo','Coreano','Dinamarques','Espanhol','Esperanto','Finlandes','Frances','Galego','Gales','Grego','Hebraico','Ingles','Islandes','Italiano','Japones','Luxemburgues','Mandarim','Neerlandes','Noruegues','Polaco','Portugues','Russo','Sueco','Turco','Ucraniano'],
    'listaComAcento': ['Alemão','Basco','Catalão','Checo','Coreano','Dinamarquês','Espanhol','Esperanto','Finlandês','Francês','Galego','Galês','Grego','Hebraico','Inglês','Islandês','Italiano','Japonês','Luxemburguês','Mandarim','Neerlandês','Norueguês','Polaco','Português','Russo','Sueco','Turco','Ucraniano'],
    'listaEmIngles': ['German','Basque','Catalan','Czech','Korean','Danish','Spanish','Esperanto','Finnish','French','Galician','Welsh','Greek','Hebrew','English','Icelandic','Italian','Japanese','Luxembourgish','Mandarin Chinese','Dutch','Norwegian','Polish','Portuguese','Russian','Sueco','Turkish','Ukranian'],
    'bol': False,
    'indice' : 0,
    'atual': '',
    'emIngles': '',
    'indisponivel': 'Este idioma ainda não está disponível. Por favor, escolha um idioma da lista!<br>'
}

nivel = {
    'input': '',
    'bol': False,
    'indisponivel': 'Por favor, escolha um nível conforme listagem acima!<br>'
}

exame = {
    'CEFR': {
        'nome': 'CEFR',
        'niveis': ['A1','A2','B1','B2','C1','C2'],
        'tabela': '',
        'descPort':'Quadro Europeu Comum de Referência para as Línguas.',
        'desc': 'Common European Framework of Reference for Languages (Learning, Teaching, Assessment) (CEFR): A1 (lowest), A2, B1, B2, C1 and C2 (highest). '
    },
    'JLPT': {
        'nome': 'JLPT',
        'niveis': ['N5','N4','N3','N2','N1'],
        'tabela': '',
        'descPort':'Teste de Proficiência em Língua Japonesa.',
        'desc': 'official Japanese Language Proficiency Test (JLPT): N5 (lowest), N4, N3, N2 and N1 (highest). '
    }
}
instrucaoVariavel = {
    'CEFR': {
        '1': '',
        '2': '',
        '3': '',
        '4': ''
    },
    'JLPT': {
        '1': ', it\'s politeness level (尊敬語,謙譲語,丁寧語 and タメ語)',
        '2': 'politeness levels and ',
        '3': 'the reading of the kanji in brackets after the kanji and ',
        '4': '\n\nSo, the answer structure is in HTML as follow:\n\n<p>訂正\n助言\n返信\n文法\n語彙\n\n'
    },
}

formato = {
    'input': '',
    'lista': ['Atual','Proximo','Sem Limite'],
    'bol': False,
    'desc': {
      'Atual': 'suitable to my',
      'Próximo': 'one step above my',
      'Proximo': 'one step above my',
      'Sem Limite': 'regardless of its',
    },
    'indisponivel': 'Por favor, escolha um formato conforme listagem acima!<br>'
}

tabelaNiveisCEFR = '''
<table style='border-style:solid'>
  <tr>
    <th><strong>Grupo de níveis</strong></th>
    <th><strong>Nível</strong></th>
    <th><strong>Descrição</strong></th>
  </tr>

  <tr>
    <td rowspan='2'><strong>A<br>Falante básico ou elementar</strong></td>
    <td><strong>A1<br>Iniciação ou Descoberta</strong></td>
    <td>
      <ul>
        <li>Pode entender e utilizar expressões familiares do dia a dia, bem como frases básicas direcionadas a satisfazer necessidades concretas.</li>
        <li>Pode apresentar-se e responder a perguntas sobre detalhes da sua vida pessoal como, por exemplo: onde vive, pessoas que conhece ou coisas que possui.</li>
        <li>Pode ainda interagir de maneira simples com nativos desde que estes falem pausadamente, de maneira clara e que estejam dispostos a ajudar.</li>
      </ul>
    </td>
  </tr>
  <tr>
    <td><strong>A2<br>Elementar ou Plataforma</strong></td>
    <td>
      <ul>
        <li>Pode entender frases e expressões relacionadas com áreas familiares ao utilizador, como informações pessoais e familiares básicas, compras, geografia local, emprego.</li>
        <li>Pode comunicar de maneira simples em situações familiares que requerem troca de informações curtas e precisas.</li>
        <li>Pode descrever de maneira superficial aspetos sobre os seus conhecimentos, o ambiente onde vive e as necessidades imediatas.</li>
      </ul>
    </td>
  </tr>

  <tr>
    <td rowspan='2'><strong>B<br>Falante independente</strong></td>
    <td><strong>B1<br>Limiar ou Intermédio</strong></td>"
    <td>
      <ul>
        <li>Pode entender os pontos principais sobre os assuntos do dia a dia como trabalho, escola e lazer.</li>
        <li>Pode lidar com situações quotidianas no país onde a língua é falada (viagem de turismo).</li>
        <li>Pode produzir textos simples sobre áreas familiares e de interesse.</li>
        <li>Pode ainda descrever experiências, eventos, sonhos, desejos e ambições.</li>
        <li>Além disso pode ainda opinar de maneira limitada sobre planos e discussões.</li>
      </ul>
    </td>
  </tr>
  <tr>
    <td><strong>B2<br>Independente</strong></td>
    <td>
      <ul>
        <li>É capaz de entender ideias principais de textos complexos que tratem de temas tanto concretos como abstratos, inclusive textos de caráter técnico se forem da sua área de especialização.</li>
        <li>Pode interagir com falantes nativos com um grau suficiente de fluência e naturalidade de forma a que a comunicação ocorra sem esforço por parte dos interlocutores.</li>
        <li>Pode produzir textos claros e detalhados sobre temas diversos, assim como defender um ponto de vista sobre temas gerais, indicando vantagens e desvantagens das várias opções.</li>
      </ul>
    </td>
  </tr>

  <tr>
    <td rowspan='2'><strong>C<br>Falante proficiente</strong></td>
    <td><strong>C1<br>Avançado ou Proficiência operativa efetiva (ou Autonomia) </strong></td>
    <td>
      <ul>
        <li>É capaz de compreender uma ampla variedade de textos extensos e com um certo nível de exigência, assim como reconhecer nestes, sentidos e idéias implícitas.</li>
        <li>Sabe expressar-se de forma fluente e espontânea sem demonstrar muitos esforços para encontrar uma palavra ou expressão adequada.</li>
        <li>Pode fazer uso efetivo do idioma para fins sociais, acadêmicos e profissionais.</li>
        <li>Pode produzir textos claros, bem estruturados e detalhados sobre temas de certa complexidade, mostrando o uso correto dos mecanismos de organização, articulação e coesão do texto.</li>
      </ul>
    </td>
  </tr>
  <tr>
    <td><strong>C2<br>Domínio pleno</strong></td>
    <td>
      <ul>
        <li>É capaz de compreender com facilidade praticamente tudo o que ouve e lê.</li>
        <li>Sabe reconstruir a informação e os argumentos procedentes de diversas fontes, seja em língua falada ou escrita, e apresentá-los de maneira coerente e resumida.</li>
        <li>Pode expressar-se espontaneamente com grande fluência e com um grau de precisão que lhe permita diferenciar pequenas matizes ou nuances de significado, inclusive em situações de maior complexidade.</li>
      </ul>
    </td>
  </tr>
</table>
'''
exame['CEFR']['tabela'] = tabelaNiveisCEFR

tabelaNiveisJLPT = "TESTE"
exame['JLPT']['tabela'] = tabelaNiveisJLPT

frasePreInicio = "<hr><h3>Aguarde uns instantes enquanto as instruções são carregadas!</h3><hr>"

fraseComecar = '''
  <h2>Então vamos começar a conversa!</h2>
  A cada pergunta que você me mandar, vou verificar se há erros gramaticais ou de sintaxe.
  Se houver, vou corrigir e informar o que está errado. Se estiver tudo bem, vou dizer também.<br>
  Vou verificar se o seu texto soa natural e se é mais adequado para texto ou fala, bem como vou identificar também o nível do seu texto de acordo com o seu tipo de exame.<br>
  Caso não soe muito natural, vou sugerir como poderia ser o seu texto, mantendo o mesmo sentido e conteúdo.<br>
  No final de cada uma das minhas respostas, além de seguir o formato que você escolheu, vou explicar pontos gramaticais desconhecidos para o seu nível.<br>
  Vou incluir também um mini-glossário com as palavras fora do seu nível, juntamente com o tipo da palavra e o nível aproximado.<br>
'''

fraseFormatoFinal = '''
<ul>
  <li><strong>Atual</strong>: use palavras e expressões do meu nível ou abaixo;</li>
  <li><strong>Próximo</strong>: quando possível, use palavras e expressões do próximo nível;</li>
  <li><strong>Sem Limite</strong>: quando possível, use palavras e expressões acima do meu nível, qualquer um;</li>
</ul>
Escolha entre <strong>Atual</strong>, <strong>Próximo</strong> e <strong>Sem Limite</strong>:<br>
'''
fraseAbertura = "<h2>Boas vindas ao LangBot!</h2><br>Estou aqui para te auxiliar no seu aprendizado de idiomas. Para podermos começar, preciso saber algumas coisas. Por favor, selecione um dos seguintes idiomas:<br><table><tr><td><ul>"

instIni0 = 'Assume the role of an expert '
#idioma
instIni1 = ' language teacher. Your duty is to assist me to improve my reading skills, conversational skills and mainly vocabulary acquisition. Answer me in '
#idioma
instIni2 = ' only. Use the guidelines of the '
#exameDesc
instIni3 = 'Assume I have '
#nivel
instIni4a = " proficiency.\n\nWhat kind of useful information for language learners can you say about my text? I'm interested in corrections of my text, correct usage of my vocabulary, regency of the words I used, politeness variations that I could have used, if my text sounds like natural speech or written text and general suggestions of better ways to phrase and convey what seems to be my intent. When I don't know a word, I'll write in my language, you interpret it as it were "
#idioma
instIni4b = ". Analyze my next text. It will be 'My text'.\n\nPresent your complete analysis in an HTML format, fully in "
#idioma
instIni5 = ", with easy to read formatting, such as bullet points, tables, headings, topics, themes, etcetera. "
instIni6 = {
    'CEFR': '',
    'JLPT': 'In the analysis, put the kanji reading in brackets after each word that is above my level. '
}
instIni7 = "No need to show vocabulary I have used or explain grammar that I have used.\n\nAfter that, answer my text, so I may follow you up in this conversation. This will be 'Your answer'.\n\nAnalyze 'Your answer'. Present me a grammar section explaining structures or expressions that you have used that are above my level, indicating which level they belong. Then, present a vocabulary section with the words of your answer, containing only the words that you used that are above my level or words that are related to the theme of the conversation. You must also include words that are above my level that you used in the previous analysis of my text and in this grammar section. To each word show "
instIni8 = {
    'CEFR':'the type of the word, the CEFR ',
    'JLPT':"the reading of the kanji in kana, the type of the word, the JLPT "
}
instIni9 = "level of the word and the Portuguese translation after it. "
instIni10 = {
    'CEFR':'',
    'JLPT':"Use this format: \n洪水「こうずい」（普通名詞）[N1]：Enchente;\n発生「はっせい」（名［スル］）[N1]：Surgir;"
}
instIni11 = "\n\nFollow these instructions step by step. Answer only with '|@@|' if you understood the instructions."

# %%
#inicio da montagem
controleVoltas = 0
for lingua in idioma['listaComAcento']:
  if (controleVoltas % 10) == 0: fraseAbertura += "</ul></td><td><ul>"
  fraseAbertura += "<li>" + lingua + "</li>"
  controleVoltas += 1
fraseAbertura += "</ul></td></tr></table><br>Informe o idioma que você quer estudar:<br>"
print_html(fraseAbertura)

idioma['input'] = input().strip()
testeSaida = idioma['input'].casefold().strip()
if testeSaida == 'desligar bot': runtime.unassign()
idioma['input'] = unidecode(idioma['input'].capitalize().strip())

while idioma['bol'] == False:
  if (idioma['input'] in idioma['listaSemAcento']) == True:
    idioma['bol'] = True
    idioma['indice'] = idioma['listaSemAcento'].index(idioma['input'])
  else:
    print_html(idioma['indisponivel'])
    idioma['input'] = input().strip()
    testeSaida = idioma['input'].casefold()
    if testeSaida == 'desligar bot': runtime.unassign()
    idioma['input'] = unidecode(idioma['input'].capitalize())

idioma['atual'] = idioma['listaComAcento'][idioma['indice']]
idioma['emIngles'] = idioma['listaEmIngles'][idioma['indice']]

if idioma['atual'] == "Japonês":
  exameNome = 'JLPT'
else:
  exameNome = 'CEFR'

fraseNivel = "<hr>Agora que você escolheu o idioma <strong>"+idioma['atual']+"</strong>, preciso saber qual o seu nível de acordo com o "
fraseNivel += exame[exameNome]['descPort']
fraseNivel += "<br>Escolha entre os níveis:<br><br>"
fraseNivel += exame[exameNome]['tabela']
fraseNivel += "<br>Seu nível:<br>"

print_html(fraseNivel)

nivel['input'] = input()
testeSaida = nivel['input'].casefold()
if testeSaida == 'desligar bot': runtime.unassign()
nivel['input'] = nivel['input'].capitalize()

while nivel['bol'] == False:
  if (nivel['input'] in exame[exameNome]['niveis']) == True:
    nivel['bol'] = True
  else:
    print_html(nivel['indisponivel'])
    nivel['input'] = input()
    testeSaida = nivel['input'].casefold()
    if testeSaida == 'desligar bot': runtime.unassign()
    nivel['input'] = nivel['input'].capitalize()

#fraseFormato = "<hr>Muito bem, seu nível é o <strong>"+ nivel['input'] +"</strong>! Por fim, preciso que você escolha como quer conduzir nossa conversa:<br>"
#fraseFormato += fraseFormatoFinal
#print_html(fraseFormato)
#
#formato['input'] = unidecode(input().title())
#testeSaida = formato['input'].casefold()
#if testeSaida == 'desligar bot': runtime.unassign()
#while formato['bol'] == False:
#  if (formato['input'] in formato['lista']) == True:
#    formato['bol'] = True
#  else:
#    print_html(formato['indisponivel'])
#    formato['input'] = input()
#    testeSaida = formato['input'].casefold()
#    if testeSaida == 'desligar bot': runtime.unassign()

fraseComecar += "<hr>Muito bem, seu nível é o <strong>"+ nivel['input'] +"</strong>!<br><h3>Importante!</h3> Todas as minhas respostas e interações daqui para frente serão em <strong>"+idioma['atual']+"</strong>!<hr> <strong>Sua primeira pergunta:</strong><br>"
print_html(frasePreInicio)

instrucaoInicial = instIni0 + idioma['emIngles'] + instIni1 + idioma['emIngles'] + instIni2 + str(exame[exameNome]['desc'])
instrucaoInicial += instIni3 + nivel['input'] + instIni4a + idioma['emIngles'] + instIni4b + idioma['emIngles'] + instIni5
instrucaoInicial += instIni6[exame[exameNome]['nome']] + instIni7 + instIni8[exame[exameNome]['nome']] + instIni9
instrucaoInicial += instIni10[exame[exameNome]['nome']] + instIni11
#print_html(instrucaoInicial)

checkInicial = False
while checkInicial == False:
  chat = model.start_chat(history=[])
  response = chat.send_message(instrucaoInicial)
  #response = model.generate_content(instrucaoInicial)
  checkInicial = "|@@|" in response.text

if checkInicial == True:
  print_html(fraseComecar)
  prompt = input()
  while prompt.casefold() != "desligar bot":
    response = chat.send_message(prompt)
    resposta = {
        'HTML':"<hr><strong>LangBot HTML</strong>:<br>"+ response.text + "<hr>",
        'MD':"**LangBot MD**:\n\n"+ response.text + " --- "
    }
    #print_html(resposta['HTML'])
    print_html("<hr>")
    print_md(resposta['MD'])
    prompt = input()
# Out:
# <html><body><h2>Boas vindas ao LangBot!</h2><br>Estou aqui para te auxiliar no seu aprendizado de idiomas. Para podermos começar, preciso saber algumas coisas. Por favor, selecione um dos seguintes idiomas:<br><table><tr><td><ul></ul></td><td><ul><li>Alemão</li><li>Basco</li><li>Catalão</li><li>Checo</li><li>Coreano</li><li>Dinamarquês</li><li>Espanhol</li><li>Esperanto</li><li>Finlandês</li><li>Francês</li></ul></td><td><ul><li>Galego</li><li>Galês</li><li>Grego</li><li>Hebraico</li><li>Inglês</li><li>Islandês</li><li>Italiano</li><li>Japonês</li><li>Luxemburguês</li><li>Mandarim</li></ul></td><td><ul><li>Neerlandês</li><li>Norueguês</li><li>Polaco</li><li>Português</li><li>Russo</li><li>Sueco</li><li>Turco</li><li>Ucraniano</li></ul></td></tr></table><br>Informe o idioma que você quer estudar:<br></body></html>
# ingles
# ...
